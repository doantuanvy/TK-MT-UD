# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.graphics.gofplots as qqplot
data = pd.read_csv('D:/tuanvy/TK-UD_MT/DataSet/babies.txt', sep='\s+')
x1=data.query('smoke==1').count()
x2=data.query('smoke==0').count()
data1= pd.DataFrame(data,columns=['bwt','smoke']).query('smoke==1')

x3=data1['bwt'].min()
x4=data1['bwt'].mean()
x5=data1['bwt'].std()
x6=data1['bwt'].var()
x7=data1['bwt'].median()
x8=data1['bwt'].quantile(.75)
x9=data1['bwt'].skew()
x10=data1['bwt'].kurtosis(axis=None)

# x3=data['bwt','smoke'].query('smoke==1').min()
x3,x4,x5,x6,x7,x8,x9,x10
hist= plt.subplot()
hist=data1['bwt'].hist(bins=10)
boxplot= plt.subplots()
plt.title('aga')
plt.ylabel('can nang')
plt.xlabel('1')
boxplot= data.boxplot(column=['bwt'])
a= plt.subplot()
a=qqplot.qqplot(data1['bwt'], line='s')

a=plt.show()


# data1=pd.DataFrame(data,columns=['bwt','smoke']).query('smoke'==1)
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
