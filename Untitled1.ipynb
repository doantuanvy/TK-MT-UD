# %%
import pandas as pd
import matplotlib.pyplot as plt
data= pd.read_excel('D:/tuanvy/TK-UD_MT/DataSet/12_ELECTRIC.xls').loc[0:21, ['kWh','AvTemp']]
plt.scatter(data['AvTemp'],data['kWh'], color='#2ecc71')
plt.title('Tiêu thụ năng lượng và nhiệt độ')
plt.xlabel('AvTemp')
plt.ylabel('kWh')
plt.show()
