# %%
import pandas as pd
data= pd.DataFrame({
'College':['Public 2-year','Public 4-year','Private 2-year','Private 4-year'],'Relative Prequency':[36.8,40.0,1.6,21.9]})
ax= data.plot.bar(x='College',y='Relative Prequency',rot=0)
