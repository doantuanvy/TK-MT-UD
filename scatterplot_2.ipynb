# %%
import pandas as pd
data= pd.read_excel('D:/tuanvy/TK-UD_MT/DataSet/12_ELECTRIC.xls').iloc[0:21]
ax1=data.plot.scatter(x='AvTemp',y='kWh')

# %%
import pandas as pd
data= pd.read_excel('D:/tuanvy/TK-UD_MT/DataSet/12_ELECTRIC.xls').loc[0:21]
ax1=data.plot.scatter(x='AvTemp',y='kWh')

# %%
import pandas as pd
data= pd.read_excel('D:/tuanvy/TK-UD_MT/DataSet/12_ELECTRIC.xls').head(20)
ax1=data.plot.scatter(x='AvTemp',y='kWh')
